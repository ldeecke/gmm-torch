# %%
# %autoreload 9

import torch
import numpy as np
import matplotlib.pyplot as plt
import gmm
from example import plot
from gumbel_regression import *

def create_data():
    np.random.seed(0)
    n_per_cluster = 40
    means = np.array([[0,0], [-5,5], [5,5]])
    X = np.vstack([np.random.randn(n_per_cluster, 2) + mu for mu in means])
    for p_idx, point in enumerate(X):
            plt.scatter(X[p_idx, 0], X[p_idx, 1], color='blue', s = 10)
    return torch.Tensor(X)

# %%
def main():
    X = create_data()
    g_fitter = gmm.GaussianMixture(n_components=3, n_features=2)
    print(g_fitter.fit(torch.Tensor(X)))
    n = 120
    K = 3

    V = torch.zeros(n, requires_grad=True) 
    V_mean = torch.mean(V)

    def gumbel_stable_loss(z, clip=None):
        if clip is not None:
            z = torch.clamp(z, max=clip)

        max_z = torch.max(z)
        max_z = torch.where(max_z < -1.0, torch.tensor(-1.0, dtype=torch.double, device=max_z.device), max_z)
        max_z = max_z.detach()  # Detach the gradients
        loss = torch.exp(z - max_z) - z*torch.exp(-max_z) - torch.exp(-max_z)    # scale by e^max_z
        return loss

    def loss_fn(V, logP):
        # loss = gumbel_stable_loss(logP - V, clip=10) # + logP
        loss = torch.mean(torch.exp(logP-V) - V - 1)
        
        z = logP - V
        max_z = torch.max(z)
        max_z = torch.where(max_z < -1.0, torch.tensor(-1.0, dtype=torch.double, device=max_z.device), max_z)
        max_z = max_z.detach()  # Detach the gradients
        loss = loss * torch.exp(-max_z)
        return loss

    V_lr = 0.01
    # loss_fn = gumbel_stable_loss
    # print(data)

    max_iter = 1000
    V_optim = torch.optim.Adam([V], lr=V_lr)
    data = X
    logP = g_fitter._estimate_log_prob(data)
    loss = loss_fn(V, logP)
    print("Initial loss:", loss.mean())
    print("initial mu", g_fitter.mu)
    g_fitter.mu = torch.nn.Parameter(torch.randn(1, 3, 2), requires_grad=False)
    print("next mu", g_fitter.mu)
    # print(g_fitter._estimate_log_prob(data))
    print("First datapoint:", data[0])

    for i in range(max_iter):
        y = g_fitter.predict(data)
        if i % 10 == 0:
            print("I", i)
            plot(data, y, i)

        # Do V step

        data = X
        logP = g_fitter._estimate_log_prob(data)

        V_optim.zero_grad()
        # loss = torch.mean(loss_fn(data-V))
        loss = loss_fn(V, logP)
        loss = loss.mean()
        loss.backward(retain_graph=True)
        V_optim.step()
        print("V0", V[0])
        print("Loss:", loss)
        print()


        # Do theta step
    #    print(logP.shape)
        weighted_log_prob = logP + np.log(1/K) * torch.ones_like(logP)
        log_prob_norm = V.unsqueeze(1).unsqueeze(2)
        log_resp = weighted_log_prob - log_prob_norm
       # print(V.shape, log_resp.shape)
        pi, mu, var = g_fitter._m_step(data, log_resp)

        g_fitter.update_pi(pi)
        g_fitter.update_mu(mu)
        g_fitter.update_var(var)

main()
# Out:
# -inf
# tensor(-3.8913)
# None
# Initial loss: tensor(-2.6436, dtype=torch.float64, grad_fn=<MeanBackward0>)
# initial mu Parameter containing:
# tensor([[[-4.9636,  5.4392],
#          [ 4.9706,  4.9009],
#          [-0.0089, -0.0522]]])
# next mu Parameter containing:
# tensor([[[-0.7602, -3.6857],
#          [ 0.6805,  1.2660],
#          [-0.2558,  0.0529]]])
# First datapoint: tensor([1.7641, 0.4002])
# I 0
# V0 tensor(0.0100, grad_fn=<SelectBackward0>)
# Loss: tensor(-2.6801, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0185, grad_fn=<SelectBackward0>)
# Loss: tensor(-0.7601, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0258, grad_fn=<SelectBackward0>)
# Loss: tensor(-0.3134, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0321, grad_fn=<SelectBackward0>)
# Loss: tensor(-0.1402, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0375, grad_fn=<SelectBackward0>)
# Loss: tensor(-0.0160, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0421, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0032, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0461, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0032, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0497, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0031, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0529, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0031, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0558, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0030, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# I 10
# V0 tensor(0.0583, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0029, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0606, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0029, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0627, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0027, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0646, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0026, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0664, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0024, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0679, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0024, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0694, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0027, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0707, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0028, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0719, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0029, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0729, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0029, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# I 20
# V0 tensor(0.0739, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0029, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0749, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0029, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0757, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0030, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0765, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0772, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0778, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0784, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0790, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0795, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0800, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# I 30
# V0 tensor(0.0805, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0809, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0813, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0817, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0821, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0824, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0827, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0830, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0833, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0836, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# I 40
# V0 tensor(0.0839, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0841, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0844, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0846, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0848, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0850, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0852, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0855, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0857, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0859, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# I 50
# V0 tensor(0.0860, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0862, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0864, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0866, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0868, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0870, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0872, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0873, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0875, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0877, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# I 60
# V0 tensor(0.0879, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0880, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0882, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0884, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0886, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0887, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0889, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0891, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0892, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0894, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# I 70
# V0 tensor(0.0896, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0898, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0899, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0901, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0903, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0905, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0907, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0908, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0910, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0912, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# I 80
# V0 tensor(0.0914, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0916, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0917, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0919, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0921, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0923, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0925, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0927, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0929, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0931, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# I 90
# V0 tensor(0.0933, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0934, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0936, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0938, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0940, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0942, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0944, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0946, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0948, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0950, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# I 100
# V0 tensor(0.0952, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0954, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0956, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0958, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0960, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0962, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0965, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0967, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0969, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0971, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# I 110
# V0 tensor(0.0973, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0975, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0977, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0979, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0981, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0984, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0986, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0988, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0990, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0992, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# I 120
# V0 tensor(0.0995, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0997, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0999, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1001, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1004, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1006, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1008, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1010, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1013, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1015, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# I 130
# V0 tensor(0.1017, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1020, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1022, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1024, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1027, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1029, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1031, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1034, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1036, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1038, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# I 140
# V0 tensor(0.1041, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1043, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1046, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1048, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1050, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1053, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1055, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1058, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1060, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1063, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# I 150
# V0 tensor(0.1065, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1068, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1070, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1073, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1075, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1078, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1080, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1083, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1086, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1088, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# I 160
# V0 tensor(0.1091, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1093, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1096, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1098, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1101, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1104, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1106, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1109, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1112, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1114, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# I 170
# V0 tensor(0.1117, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1120, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1122, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1125, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1128, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1130, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1133, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1136, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1138, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1141, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# I 180
# V0 tensor(0.1144, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1147, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1149, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1152, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1155, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1158, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1161, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1163, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1166, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1169, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# I 190
# V0 tensor(0.1172, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1175, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1178, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1180, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1183, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1186, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1189, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1192, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1195, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1198, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# I 200
# V0 tensor(0.1201, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1204, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1206, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1209, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1212, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1215, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1218, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1221, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1224, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1227, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# I 210
# V0 tensor(0.1230, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1233, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1236, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1239, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1242, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1245, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1248, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1251, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1254, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1257, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# I 220
# V0 tensor(0.1260, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1264, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1267, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1270, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1273, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1276, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1279, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1282, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1285, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1288, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# I 230
# V0 tensor(0.1292, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1295, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1298, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1301, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1304, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1307, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1311, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1314, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1317, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1320, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# I 240
# V0 tensor(0.1323, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1327, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1330, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1333, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1336, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1340, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1343, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1346, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1349, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1353, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# I 250
# V0 tensor(0.1356, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1359, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1363, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1366, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1369, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1373, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1376, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1379, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1383, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1386, grad_fn=<SelectBackward0>)
# Loss: tensor(0.0056, dtype=torch.float64, grad_fn=<MeanBackward0>)
#
# I 260
