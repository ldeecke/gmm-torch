# %%
# %autoreload 9

import torch
import numpy as np
import matplotlib.pyplot as plt
import gmm
from example import plot
from gumbel_regression import *

def create_data():
    np.random.seed(0)
    n_per_cluster = 40
    means = np.array([[0,0], [-5,5], [5,5]])
    X = np.vstack([np.random.randn(n_per_cluster, 2) + mu for mu in means])
    for p_idx, point in enumerate(X):
            plt.scatter(X[p_idx, 0], X[p_idx, 1], color='blue', s = 10)
    return torch.Tensor(X)

# %%
def main():
    X = create_data()
    g_fitter = gmm.GaussianMixture(n_components=3, n_features=2)
    print(g_fitter.fit(torch.Tensor(X)))
    n = 120
    K = 3

    V = torch.zeros(n, requires_grad=True) 
    V_mean = torch.mean(V)

    def gumbel_stable_loss(z, clip=None):
        if clip is not None:
            z = torch.clamp(z, max=clip)

        max_z = torch.max(z)
        max_z = torch.where(max_z < -1.0, torch.tensor(-1.0, dtype=torch.double, device=max_z.device), max_z)
        max_z = max_z.detach()  # Detach the gradients
        loss = torch.exp(z - max_z) - z*torch.exp(-max_z) - torch.exp(-max_z)    # scale by e^max_z
        return loss

    def loss_fn(V, logP):
        # loss = gumbel_stable_loss(logP - V, clip=10) # + logP
        loss = torch.mean(torch.exp(logP-V) - V - 1)
        return loss

    V_lr = 0.001
    # loss_fn = gumbel_stable_loss
    # print(data)

    max_iter = 100
    V_optim = torch.optim.Adam([V], lr=V_lr)
    data = X
    logP = g_fitter._estimate_log_prob(data)
    loss = loss_fn(V, logP)
    print("Initial loss:", loss.mean())
    print("initial mu", g_fitter.mu)
    g_fitter.mu = torch.nn.Parameter(torch.randn(1, 3, 2), requires_grad=False)
    print("next mu", g_fitter.mu)
    # print(g_fitter._estimate_log_prob(data))
    print("First datapoint:", data[0])

    for i in range(max_iter):
        y = g_fitter.predict(data)
        if i % 10 == 0:
            print("I", i)
            plot(data, y, i)

        # Do V step

        data = X
        logP = g_fitter._estimate_log_prob(data)

        V_optim.zero_grad()
        # loss = torch.mean(loss_fn(data-V))
        loss = loss_fn(V, logP)
        loss = loss.mean()
        loss.backward(retain_graph=True)
        V_optim.step()
        print("V0", V[0])
        print("Loss:", loss)
        print()


        # Do theta step
    #    print(logP.shape)
        weighted_log_prob = logP + np.log(1/K) * torch.ones_like(logP)
        log_prob_norm = V.unsqueeze(1).unsqueeze(2)
        log_resp = weighted_log_prob - log_prob_norm
       # print(V.shape, log_resp.shape)
        pi, mu, var = g_fitter._m_step(data, log_resp)

        g_fitter.update_pi(pi)
        g_fitter.update_mu(mu)
        g_fitter.update_var(var)

main()
# Out:
# -inf
# tensor(-3.8913)
# None
# Initial loss: tensor(-0.9725, grad_fn=<MeanBackward0>)
# initial mu Parameter containing:
# tensor([[[-4.9636,  5.4392],
#          [ 4.9706,  4.9009],
#          [-0.0089, -0.0522]]])
# next mu Parameter containing:
# tensor([[[-0.1483,  0.1326],
#          [-2.0981, -0.8472],
#          [ 0.6098, -1.6213]]])
# First datapoint: tensor([1.7641, 0.4002])
# I 0
# V0 tensor(0.0010, grad_fn=<SelectBackward0>)
# Loss: tensor(-0.9845, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0020, grad_fn=<SelectBackward0>)
# Loss: tensor(-0.9665, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0030, grad_fn=<SelectBackward0>)
# Loss: tensor(-0.9538, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0040, grad_fn=<SelectBackward0>)
# Loss: tensor(-0.9428, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0050, grad_fn=<SelectBackward0>)
# Loss: tensor(-0.9316, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0060, grad_fn=<SelectBackward0>)
# Loss: tensor(-0.9150, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0070, grad_fn=<SelectBackward0>)
# Loss: tensor(-0.8935, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0080, grad_fn=<SelectBackward0>)
# Loss: tensor(-0.8755, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0090, grad_fn=<SelectBackward0>)
# Loss: tensor(-0.8378, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0100, grad_fn=<SelectBackward0>)
# Loss: tensor(-0.7332, grad_fn=<MeanBackward0>)
#
# I 10
# V0 tensor(0.0111, grad_fn=<SelectBackward0>)
# Loss: tensor(-0.1908, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0117, grad_fn=<SelectBackward0>)
# Loss: tensor(25.5859, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0124, grad_fn=<SelectBackward0>)
# Loss: tensor(26.8299, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0132, grad_fn=<SelectBackward0>)
# Loss: tensor(26.8309, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0141, grad_fn=<SelectBackward0>)
# Loss: tensor(26.8408, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0150, grad_fn=<SelectBackward0>)
# Loss: tensor(26.8580, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0160, grad_fn=<SelectBackward0>)
# Loss: tensor(26.9086, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0170, grad_fn=<SelectBackward0>)
# Loss: tensor(27.2945, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0181, grad_fn=<SelectBackward0>)
# Loss: tensor(28.2403, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0191, grad_fn=<SelectBackward0>)
# Loss: tensor(28.2940, grad_fn=<MeanBackward0>)
#
# I 20
# V0 tensor(0.0202, grad_fn=<SelectBackward0>)
# Loss: tensor(28.5153, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0213, grad_fn=<SelectBackward0>)
# Loss: tensor(30.4375, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0224, grad_fn=<SelectBackward0>)
# Loss: tensor(37.3551, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0232, grad_fn=<SelectBackward0>)
# Loss: tensor(467.1364, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0240, grad_fn=<SelectBackward0>)
# Loss: tensor(890.3004, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0249, grad_fn=<SelectBackward0>)
# Loss: tensor(889.5946, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0259, grad_fn=<SelectBackward0>)
# Loss: tensor(888.7939, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0269, grad_fn=<SelectBackward0>)
# Loss: tensor(887.9158, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0280, grad_fn=<SelectBackward0>)
# Loss: tensor(886.9787, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0292, grad_fn=<SelectBackward0>)
# Loss: tensor(885.9930, grad_fn=<MeanBackward0>)
#
# I 30
# V0 tensor(0.0304, grad_fn=<SelectBackward0>)
# Loss: tensor(884.9699, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0316, grad_fn=<SelectBackward0>)
# Loss: tensor(883.9166, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0328, grad_fn=<SelectBackward0>)
# Loss: tensor(882.8391, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0341, grad_fn=<SelectBackward0>)
# Loss: tensor(881.7429, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0353, grad_fn=<SelectBackward0>)
# Loss: tensor(880.6311, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0366, grad_fn=<SelectBackward0>)
# Loss: tensor(879.5079, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0379, grad_fn=<SelectBackward0>)
# Loss: tensor(878.3762, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0392, grad_fn=<SelectBackward0>)
# Loss: tensor(877.2387, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0405, grad_fn=<SelectBackward0>)
# Loss: tensor(876.0973, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0418, grad_fn=<SelectBackward0>)
# Loss: tensor(874.9524, grad_fn=<MeanBackward0>)
#
# I 40
# V0 tensor(0.0431, grad_fn=<SelectBackward0>)
# Loss: tensor(873.8075, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0444, grad_fn=<SelectBackward0>)
# Loss: tensor(872.6621, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0458, grad_fn=<SelectBackward0>)
# Loss: tensor(871.5177, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0471, grad_fn=<SelectBackward0>)
# Loss: tensor(870.3755, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0484, grad_fn=<SelectBackward0>)
# Loss: tensor(869.2364, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0497, grad_fn=<SelectBackward0>)
# Loss: tensor(868.1003, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0510, grad_fn=<SelectBackward0>)
# Loss: tensor(866.9684, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0523, grad_fn=<SelectBackward0>)
# Loss: tensor(865.8405, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0536, grad_fn=<SelectBackward0>)
# Loss: tensor(864.7173, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0548, grad_fn=<SelectBackward0>)
# Loss: tensor(863.5989, grad_fn=<MeanBackward0>)
#
# I 50
# V0 tensor(0.0561, grad_fn=<SelectBackward0>)
# Loss: tensor(862.4851, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0574, grad_fn=<SelectBackward0>)
# Loss: tensor(861.3770, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0587, grad_fn=<SelectBackward0>)
# Loss: tensor(860.2744, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0599, grad_fn=<SelectBackward0>)
# Loss: tensor(859.1772, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0612, grad_fn=<SelectBackward0>)
# Loss: tensor(858.0849, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0625, grad_fn=<SelectBackward0>)
# Loss: tensor(856.9990, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0637, grad_fn=<SelectBackward0>)
# Loss: tensor(855.9184, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0650, grad_fn=<SelectBackward0>)
# Loss: tensor(854.8441, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0662, grad_fn=<SelectBackward0>)
# Loss: tensor(853.7745, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0675, grad_fn=<SelectBackward0>)
# Loss: tensor(852.7112, grad_fn=<MeanBackward0>)
#
# I 60
# V0 tensor(0.0687, grad_fn=<SelectBackward0>)
# Loss: tensor(851.6529, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0699, grad_fn=<SelectBackward0>)
# Loss: tensor(850.6003, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0711, grad_fn=<SelectBackward0>)
# Loss: tensor(849.5530, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0724, grad_fn=<SelectBackward0>)
# Loss: tensor(848.5111, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0736, grad_fn=<SelectBackward0>)
# Loss: tensor(847.4739, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0748, grad_fn=<SelectBackward0>)
# Loss: tensor(846.4426, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0760, grad_fn=<SelectBackward0>)
# Loss: tensor(845.4166, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0772, grad_fn=<SelectBackward0>)
# Loss: tensor(844.3954, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0784, grad_fn=<SelectBackward0>)
# Loss: tensor(843.3793, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0796, grad_fn=<SelectBackward0>)
# Loss: tensor(842.3676, grad_fn=<MeanBackward0>)
#
# I 70
# V0 tensor(0.0808, grad_fn=<SelectBackward0>)
# Loss: tensor(841.3614, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0820, grad_fn=<SelectBackward0>)
# Loss: tensor(840.3599, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0831, grad_fn=<SelectBackward0>)
# Loss: tensor(839.3634, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0843, grad_fn=<SelectBackward0>)
# Loss: tensor(838.3707, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0855, grad_fn=<SelectBackward0>)
# Loss: tensor(837.3834, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0867, grad_fn=<SelectBackward0>)
# Loss: tensor(836.4009, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0878, grad_fn=<SelectBackward0>)
# Loss: tensor(835.4230, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0890, grad_fn=<SelectBackward0>)
# Loss: tensor(834.4488, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0901, grad_fn=<SelectBackward0>)
# Loss: tensor(833.4807, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0913, grad_fn=<SelectBackward0>)
# Loss: tensor(832.5164, grad_fn=<MeanBackward0>)
#
# I 80
# V0 tensor(0.0925, grad_fn=<SelectBackward0>)
# Loss: tensor(831.5573, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0936, grad_fn=<SelectBackward0>)
# Loss: tensor(830.6042, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0947, grad_fn=<SelectBackward0>)
# Loss: tensor(829.6566, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0959, grad_fn=<SelectBackward0>)
# Loss: tensor(828.7164, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0970, grad_fn=<SelectBackward0>)
# Loss: tensor(827.7867, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0982, grad_fn=<SelectBackward0>)
# Loss: tensor(826.8701, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.0993, grad_fn=<SelectBackward0>)
# Loss: tensor(825.9773, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1004, grad_fn=<SelectBackward0>)
# Loss: tensor(825.1302, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1016, grad_fn=<SelectBackward0>)
# Loss: tensor(824.3917, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1027, grad_fn=<SelectBackward0>)
# Loss: tensor(823.9855, grad_fn=<MeanBackward0>)
#
# I 90
# V0 tensor(0.1038, grad_fn=<SelectBackward0>)
# Loss: tensor(825.0397, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1049, grad_fn=<SelectBackward0>)
# Loss: tensor(836.4266, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1061, grad_fn=<SelectBackward0>)
# Loss: tensor(1058.4758, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1073, grad_fn=<SelectBackward0>)
# Loss: tensor(1191.7100, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1085, grad_fn=<SelectBackward0>)
# Loss: tensor(1190.3011, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1097, grad_fn=<SelectBackward0>)
# Loss: tensor(1188.8591, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1110, grad_fn=<SelectBackward0>)
# Loss: tensor(1187.3879, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1122, grad_fn=<SelectBackward0>)
# Loss: tensor(1185.8914, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1135, grad_fn=<SelectBackward0>)
# Loss: tensor(1184.3754, grad_fn=<MeanBackward0>)
#
# V0 tensor(0.1148, grad_fn=<SelectBackward0>)
# Loss: tensor(1182.8418, grad_fn=<MeanBackward0>)
